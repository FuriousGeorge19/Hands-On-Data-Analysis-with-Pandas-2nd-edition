# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(2, 2, figsize=(12,6))

axes[0, 1].set(title = "Title 0, 0")
# Out:
# [Text(0.5, 1.0, 'Title 0, 0')]

# %%
# Out:
# [Text(0.5, 1.0, 'Title 0, 0')]
